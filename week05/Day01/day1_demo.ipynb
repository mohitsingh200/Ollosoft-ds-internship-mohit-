# %% [markdown]
# # Week 5 Day 1
#
# ## Data Sourcing
#
# Testing reusable stock downloader.

# %%
from data_loader import fetch_stocks

print("Import Successful")
# Out:
# Import Successful

# %%
tickers = [
    "^NSEI",      # Nifty 50
    "^NSEBANK",   # Bank Nifty
    "^BSESN"      # Sensex
]

# %%
df = fetch_stocks(
    tickers,
    start="2020-01-01",
    end="2025-01-01"
)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
df.head()
# Out:
#         Date  Ticker         Close
# 0 2020-01-01  ^BSESN           NaN
# 1 2020-01-02  ^BSESN  41626.640625
# 2 2020-01-03  ^BSESN  41464.609375
# 3 2020-01-06  ^BSESN  40676.628906
# 4 2020-01-07  ^BSESN  40869.468750

# %%
print(df.shape)
# Out:
# (3711, 3)

# %%
print(df["Ticker"].unique())
# Out:
# ['^BSESN' '^NSEBANK' '^NSEI']

# %%
print(df.isnull().sum())
# Out:
# Date      0
# Ticker    0
# Close     3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3711 entries, 0 to 3710
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3711 non-null   datetime64[ns]
#  1   Ticker  3711 non-null   object
#  2   Close   3708 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 87.1+ KB

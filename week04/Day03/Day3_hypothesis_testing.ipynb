# %% [markdown]
# # Week 4 Day 3
#
# # Hypothesis Testing on Stock Returns
#
# ## Objectives
#
# 1. Test whether Reliance mean daily return differs from zero.
# 2. Test whether Reliance and TCS have different mean returns.
# 3. Interpret p-values and make decisions.

# %%
import pandas as pd
import numpy as np

import yfinance as yf

from scipy.stats import ttest_1samp
from scipy.stats import ttest_ind

# %%
reliance = yf.download(
    "RELIANCE.NS",
    period="5y",
    auto_adjust=True
)

tcs = yf.download(
    "TCS.NS",
    period="5y",
    auto_adjust=True
)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
if isinstance(reliance.columns, pd.MultiIndex):
    reliance.columns = reliance.columns.get_level_values(0)

if isinstance(tcs.columns, pd.MultiIndex):
    tcs.columns = tcs.columns.get_level_values(0)

# %%
reliance_returns = (
    reliance["Close"]
    .pct_change()
    .dropna()
)

tcs_returns = (
    tcs["Close"]
    .pct_change()
    .dropna()
)

# %% [markdown]
# ## One-Sample t-Test
#
# ### H₀:
# Mean daily return of Reliance = 0
#
# ### H₁:
# Mean daily return of Reliance ≠ 0

# %%
t_stat, p_value = ttest_1samp(
    reliance_returns,
    popmean=0
)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: 0.9207741664623723
# P-value: 0.35734816652869883

# %%
alpha = 0.05

if p_value < alpha:
    print("Reject H0")
else:
    print("Fail to Reject H0")
# Out:
# Fail to Reject H0

# %% [markdown]
# ## Interpretation
#
# If p-value < 0.05:
#
# We reject the null hypothesis and conclude that the mean daily return of Reliance is significantly different from zero.
#
# Otherwise:
#
# There is insufficient evidence to conclude that the mean daily return differs from zero.

# %% [markdown]
# ## Two-Sample t-Test
#
# ### H₀:
# Mean return of Reliance = Mean return of TCS
#
# ### H₁:
# Mean return of Reliance ≠ Mean return of TCS

# %%
t_stat2, p_value2 = ttest_ind(
    reliance_returns,
    tcs_returns,
    equal_var=False
)

print("T-statistic:", t_stat2)
print("P-value:", p_value2)
# Out:
# T-statistic: 0.9649604085420177
# P-value: 0.33465915957143333

# %%
alpha = 0.05

if p_value2 < alpha:
    print("Reject H0")
else:
    print("Fail to Reject H0")
# Out:
# Fail to Reject H0

# %% [markdown]
# # Final Conclusion
#
# ### One-Sample Test
#
# The one-sample t-test was used to determine whether the mean daily return of Reliance differs significantly from zero.
#
# Decision:
# (The one-sample t-test failed to reject the null hypothesis, indicating that Reliance's mean return is not significantly different from zero.
#
# The Welch's two-sample t-test also failed to reject the null hypothesis, suggesting that the mean returns of Reliance and TCS are not significantly different.)
#
#
# ### Two-Sample Test
#
# The two-sample t-test was used to compare the mean daily returns of Reliance and TCS.
#
# Decision:
# (Write your result based on p-value.)
#
#
# ### Overall Learning
#
# Hypothesis testing provides a statistical framework for deciding whether observed differences are likely due to chance or represent real effects in the data.

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
reliance = yf.download(
    "RELIANCE.NS",
    period="2y"
)

reliance.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2024-06-10  1453.867432  1475.555836  1450.581979  1452.434637     9251760
# 2024-06-11  1439.317993  1456.115429  1437.341824  1451.496086    11774902
# 2024-06-12  1445.888672  1458.412691  1437.835880  1440.133128    10081742
# 2024-06-13  1447.790649  1454.707240  1442.701991  1454.460219     9181160
# 2024-06-14  1459.944092  1462.043771  1439.861205  1452.484007     8157998

# %%
print(reliance.shape)
print(reliance.columns)
# Out:
# (497, 5)
# MultiIndex([( 'Close', 'RELIANCE.NS'),
#             (  'High', 'RELIANCE.NS'),
#             (   'Low', 'RELIANCE.NS'),
#             (  'Open', 'RELIANCE.NS'),
#             ('Volume', 'RELIANCE.NS')],
#            names=['Price', 'Ticker'])

# %%
plt.figure(figsize=(12,6))

plt.plot(
    reliance.index,
    reliance["Close"],
    label="Reliance Close Price"
)

# %%
plt.title("Reliance Closing Price (Last 2 Years)")
# Out:
# Text(0.5, 1.0, 'Reliance Closing Price (Last 2 Years)')

# %%
plt.xlabel("Date")
plt.ylabel("Closing Price")
# Out:
# Text(0, 0.5, 'Closing Price')

# %%
plt.legend()
# Out:
# C:\Users\Ms642\AppData\Local\Temp\ipykernel_9120\4061938096.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.grid(True)

# %%
plt.show()

# %%
plt.figure(figsize=(12,6))

plt.plot(
    reliance.index,
    reliance["Close"],
    label="Reliance Close Price"
)

plt.title("Reliance Closing Price (Last 2 Years)")
plt.xlabel("Date")
plt.ylabel("Closing Price")

plt.legend()

plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.plot(
    reliance.index,
    reliance["Close"],
    label="Reliance Close Price"
)

plt.title("Reliance Closing Price (Last 2 Years)")
plt.xlabel("Date")
plt.ylabel("Closing Price")

plt.legend()
plt.grid(True)

plt.savefig(
    "../Day01/images/reliance_close_price.png",
    dpi=150
)

plt.show()
